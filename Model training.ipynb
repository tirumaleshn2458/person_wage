# %% [markdown]
# # Model training

# %%
import pandas as pd
import numpy as np

# %%
before_trans=pd.read_csv('before_trans.csv')

# %%
after_trans=pd.read_csv('after_trans.csv')

# %%
final_data=pd.read_csv('final_data.csv')

# %%
before_trans.head()
# Out:
#    age  workclass  fnlwgt  education  education_num  marital_status  \
# 0   39          4   77516         13             13               5
# 1   50          7   83311         13             13               6
# 2   38          8  215646         15              9               4
# 3   53          8  234721         10              7               6
# 4   28          8  338409         13             13               6
#
#    occupation  relationship  race  sex  capital_gain  capital_loss  \
# 0          11             4     4    1          2174             0
# 1          12             5     4    1             0             0
# 2           5             4     4    1             0             0
# 3           5             5     3    1             0             0
# 4          14             1     3    0             0             0
#
#    hours_per_week  native_country  wage_class
# 0              40              41           1
# 1              13              41           1
# ...

# %%
after_trans.head()
# Out:
#         age  workclass     fnlwgt  education  education_num  marital_status  \
# 0  3.663562          4  11.258240         13             13               5
# 1  3.912023          7  11.330336         13             13               6
# 2  3.637586          8  12.281393         15              9               4
# 3  3.970292          8  12.366153         10              7               6
# 4  3.332205          8  12.732011         13             13               6
#
#    occupation  relationship  race  sex  capital_gain  capital_loss  \
# 0          11             4     4    1          2174             0
# 1          12             5     4    1             0             0
# 2           5             4     4    1             0             0
# 3           5             5     3    1             0             0
# 4          14             1     3    0             0             0
#
#    hours_per_week  native_country  wage_class
# 0        3.688879              41           1
# ...

# %%
final_data.head()
# Out:
#         age  education  education_num  marital_status  occupation  \
# 0  0.540509   0.866667       0.800000        0.833333    0.785714
# 1  0.702243   0.866667       0.800000        1.000000    0.857143
# 2  0.523600   1.000000       0.533333        0.666667    0.357143
# 3  0.740173   0.666667       0.400000        1.000000    0.357143
# 4  0.324814   0.866667       0.800000        1.000000    1.000000
#
#    relationship  sex  capital_gain  wage_class
# 0           0.8  1.0      0.098639           1
# 1           1.0  1.0      0.000000           1
# 2           0.8  1.0      0.000000           1
# 3           1.0  1.0      0.000000           1
# 4           0.2  0.0      0.000000           1

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
model=MinMaxScaler()

# %%
model.fit(after_trans.iloc[:,:-1])
# Out:
# MinMaxScaler()

# %%
model.transform([[3.663562,4,11.258240,13,13,5,11,4,4,1,2174,0,3.688879,41]])
# Out:
# array([[0.54050905, 0.5       , 0.49534848, 0.86666667, 0.8       ,
#         0.83333333, 0.78571429, 0.8       , 1.        , 1.        ,
#         0.09863884, 0.        , 0.8492275 , 1.        ]])
